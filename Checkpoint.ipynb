# %% [markdown]
# Gabriel Antony Cadima Ciziks - RM98215
#
# Lucca Sabatini Tambellini - RM98169

# %%
from GraphGenerator import GraphGenerator
gg = GraphGenerator()

# %% [markdown]
# # Pergunta 1
# ## Existe uma correlação entre o número de filmes dirigidos e a avaliação média do Tomatômetro?
#
# ### Observações sobre o gráfico:
#
# Linha de Tendência (Regressão Linear): A linha de tendência vermelha mostra uma inclinação positiva, indicando uma leve correlação positiva entre o número de filmes dirigidos e a classificação média. Isso sugere que, à medida que os diretores dirigem mais filmes, suas classificações médias tendem a aumentar.
#
# Dispersão dos Pontos: Embora a linha vermelha mostre uma tendência positiva, os pontos de dados estão amplamente dispersos, especialmente para diretores com menos filmes. Para contagens mais baixas de filmes (menos de 10), há uma grande variabilidade nas classificações, o que sugere que ter apenas alguns filmes não garante classificações mais altas ou mais baixas.
#
# ### Reposta:
#
# Sim, o gráfico mostra uma correlação positiva entre o número de filmes dirigidos e a classificação média no Tomatometer. Podemos sugerir que, com mais experiência (ou seja, mais filmes), os diretores podem produzir filmes com melhores classificações.

# %%
gg.dist_num_rating()

# %% [markdown]
# # Pergunta 2
# ## De acordo com as classificações do Tomatometer descritas neste gráfico para os melhores e piores filmes de cada diretor listado, qual diretor tem maior consistência entre seus filmes lançados?
#
# ### Observações sobre o gráfico
#
# Diretores Considerados: Foram considerados para comparação apenas o **top10** diretores com maiores médias de avaliação possuindo mais que 3 filmes.
# Variância: Consideramos como variância a diferença entre a avaliação mais positiva e a mais negativa dos diretores, levando em consideração o peso das notas.
#
# ### Resposta
#
# Ao observar a variância de cada diretor, podemos considerar que o Robert Bresson seria o diretor mais consistente, visto que mesmo com 4 filmes, apresenta seu pior filme com 95 de Nota, e seu melhor com 100 de Nota.

# %%
gg.graph_best_worst(10)

# %% [markdown]
# ### Observações sobre o gráfico
#
# Diretores Considerados: Foram considerados para comparação apenas o **top20** diretores com maiores médias de avaliação possuindo mais que 3 filmes.
#
# # Pergunta 3
# ## Há algum diretor destoante dos demais dentre aqueles com melhores médias?
#
# ### Resposta
#
# Sim, o diretor Charles Chaplin com 9 filmes dirigidos e uma média de nota cheia de 97, demonstrando uma consistência absurda. Além dele, o diretor Akira Kurosawa, pelos dados, sendo o único dos diretores do top20 com mais de 10 filmes a com uma média altíssima de 94,18.

# %%
gg.graph_count_rating()

# %% [markdown]
# # Pergunta 4
# ## Há alguma diferença entre a forma em que os críticos e a audiência avaliam os filmes?
#
# ### Resposta
#
# Sim, o gráfico indica que a audiência é mais propensa a apresentar uma nota média aos filmes do que os críticos, isto é, a audiência dificilmente avalia pelas pontas(0 ou 100) mantendo-se nas notas médias (40-80), semelhante a uma parábola invertida, ao contrário dos críticos que avaliam como 0 ou 100 mais frequentemente.
#
# # Pergunta 5
# ## Há algo nos gráficos que surpreende?
# ### Resposta
#
# Sim, pois é comum imaginar duas coisas:
# - Os críticos, por avaliarem mais rigidamente os filmes levando extremamente em conta fatores técnicos, não dariam notas mínimas ou máximas aos filmes com frequência
# - A audiência, por relevar fatores técnicos e ter um fator emocional forte ligado ao filme (positivo ou negativo), dariam notas extremas com frequência
#
# **Contudo** nota-se exatamente o oposto das concepções comuns, o que surpreende! Os críticos são mais extremos com muita mais frequência do que a audiência por muita diferença!

# %%
gg.graph_critics_audience()

# %% [markdown]
# ### Observações sobre o gráfico
# Top 10 considerado: Foi definido pelos filmes mais avaliados pela audiência da história do RottenTomatoes
#
# # Pergunta 6
# ## Há algum filme destoante em questão da avaliação dos críticos e da audiência?
#
# ### Resposta
# Sim, não só um como dois... o filme Gladiador é o único filme do top 10 em que a audiência avaliou melhor do que os críticos, e American Pie incrivelmente possui a mesma nota tanto de críticos quanto da audiência.
#
# # Pergunta 7
# ## Há algum motivo para os críticos avaliarem melhor os filmes do top 10?
# ### Resposta
# Sim, a diferença pode ser dada através da quantidade de notas, isto é, por serem os 10 filmes mais avaliados pela audiência, dificulta-se muito a nota se manter tão alta já que envolve a opinião de um grupo muito maior do que o grupo dos críticos, que é muito mais fácil manter uma média alta/baixa por estar em menor número.

# %%
gg.top_movies_comparison()

# %% [markdown]
# # Pergunta 8
# ## Qual é a faixa de duração mais comum para os filmes?
#
# ### Resposta
# A faixa de duração mais comum para os filmes parece estar entre 80 e 120 minutos, já que essa faixa tem a maior quantidade de filmes.
#
# # Pergunta 9
# ## Alguma observação notória que o gráfico nos permita fazer?
# ### Resposta
# É interessante ver que há mais filmes próximos de 3 horas (180 minutos) do que menores que 1 hora, pois se espera que seja mais fácil produzir filmes/mini-filmes de menor duração do que filmes de duração muito extensas.

# %%
gg.graph_movie_time()

# %% [markdown]
# # Pergunta 10
# ## O que explica o aumento repentino de filmes adicionados entre 2016-2019?
#
# ### Resposta
# O aumento se dá pelo aumento do uso da Netflix pelas pessoas, isto é, por ter tido um boom de popularidade de 2016 para 2017, a Netflix buscou aumentar seu catalogo adicionando mais filmes.

# %%
gg.netflix_releases()
